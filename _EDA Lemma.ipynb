# %%
import pandas as pd

# %% [markdown]
# Basic EDA(Exploratory Data Analysis)

# %%
df=pd.read_csv("C:/Users/Prathmesh Ingole/Downloads/lemma_industry_grade_doooh_dataset.csv")
df
# Out:
#     CampaignID   Client       Industry       City            ScreenType  \
# 0        C0001    Pepsi         Retail  Hyderabad          Metro Screen
# 1        C0002  OnePlus  Entertainment       Pune     Outdoor Billboard
# 2        C0003     Boat  Entertainment  Bangalore  Shopping Mall Screen
# 3        C0004  Netflix     Technology      Delhi          Metro Screen
# 4        C0005    Paytm     Technology       Pune  Shopping Mall Screen
# ..         ...      ...            ...        ...                   ...
# 995      C0996    Apple        Fintech     Mumbai        Airport Screen
# 996      C0997  OnePlus  Entertainment  Bangalore        Airport Screen
# 997      C0998     Nike     Audio Tech  Ahmedabad        Airport Screen
# 998      C0999   Adidas           Food       Pune     Outdoor Billboard
# 999      C1000   Lenovo     E-commerce  Ahmedabad     Outdoor Billboard
#
#            AdType  Impressions  Clicks   CTR  Spend_INR  ...  \
# ...

# %% [markdown]
# Check Dataset shape

# %%
df.shape
# Out:
# (1000, 28)

# %% [markdown]
# No Of Rows=1000
# No of columns=28

# %%
# Understanding the data types of fields numeric or categorical
df.dtypes
# Out:
# CampaignID                 object
# Client                     object
# Industry                   object
# City                       object
# ScreenType                 object
# AdType                     object
# Impressions                 int64
# Clicks                      int64
# CTR                       float64
# Spend_INR                   int64
# ScreenTime_HoursPerDay      int64
# RunningTime_Hours           int64
# Duration_days               int64
# AudienceType               object
# Date                       object
# ScreenResolution           object
# impressions                 int64
# screen_id                  object
# weather_condition          object
# time_slot                  object
# adjusted_impressions        int64
# cpm                       float64
# revenue                   float64
# ad_spend                  float64
# roi_percent               float64
# click_through_rate        float64
# estimated_clicks            int64
# ...

# %%
# finding the Missing values.
# and checking if cleaning is required or not

df.isna().sum()
# Out:
# CampaignID                0
# Client                    0
# Industry                  0
# City                      0
# ScreenType                0
# AdType                    0
# Impressions               0
# Clicks                    0
# CTR                       0
# Spend_INR                 0
# ScreenTime_HoursPerDay    0
# RunningTime_Hours         0
# Duration_days             0
# AudienceType              0
# Date                      0
# ScreenResolution          0
# impressions               0
# screen_id                 0
# weather_condition         0
# time_slot                 0
# adjusted_impressions      0
# cpm                       0
# revenue                   0
# ad_spend                  0
# roi_percent               0
# click_through_rate        0
# estimated_clicks          0
# campaign_performance      0
# dtype: int64

# %% [markdown]
#  So There is no Null Values in this Dataset therefore no Cleaning required

# %%
df.duplicated()
duplicates=df[df.duplicated()]
print(duplicates)
df.duplicated().sum()
# Out:
# Empty DataFrame
# Columns: [CampaignID, Client, Industry, City, ScreenType, AdType, Impressions, Clicks, CTR, Spend_INR, ScreenTime_HoursPerDay, RunningTime_Hours, Duration_days, AudienceType, Date, ScreenResolution, impressions, screen_id, weather_condition, time_slot, adjusted_impressions, cpm, revenue, ad_spend, roi_percent, click_through_rate, estimated_clicks, campaign_performance]
# Index: []
#
# [0 rows x 28 columns]
# np.int64(0)

# %% [markdown]
# There is no duplicates values
